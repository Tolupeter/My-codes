# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Protein kinase B activation',
        'Humoral immune response',
        'Positive regulation of ERK signaling',
        'Viral process'
    ],
    '-log10(adj p-value)': [
        3.131654862,
        2.631459122,
        2.567557024,
        2.562401837,
        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#bb0c00'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotM2up.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotM2upOV.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Extracellular matrix organization',
        'Collagen fibril organization',
        'Cellular response to TGF-β',
        
        
    ],
    '-log10(adj p-value)': [
        10.29836152,
        9.408176655,
        4.77773094,
        
        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#4169E1'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotm2AYOV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotm2AYOV.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Cytoplasmic translation',
        'Translation at postsynapse',
        'Oxidative phosphorylation',
        'Ribosome biogenesis',
        'Cellular respiration',
        'Exogenous antigen presentation'
    ],
    '-log10(adj p-value)': [
        73.09378329,
        46.57243152,
        20.46915426,
        20.32476919,
        20.2104719,
        17.87783727
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#bb0c00'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotDENDRITIC.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotDENDRITIC.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Humoral immune response',
        'Receptor-mediated endocytosis',
        'Complement activation',
        'Lymphocyte proliferation',
        'Mononuclear cell proliferation',
        'Regulation of endocytosis'
    ],
    '-log10(adj p-value)': [
        9.67205327,
        9.223023567,
        8.858919213,
        8.18207419,
        8.109964846,
        7.908699114


    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values for clearer plotting
df = df.sort_values('-log10(adj p-value)', ascending=True)

# Plot
plt.figure(figsize=(5, 2))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#bb0c00'
)

# Formatting
ax.set_title('GO BP', fontsize=12)
ax.set_xlabel('-log10(adj p-value)', fontsize=12)
ax.set_ylabel('')  # Remove y-axis label

# Remove top and right spines (black lines)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plot.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plot.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Myeloid leukocyte migration',
        'Humoral immune response',
        'Cell chemotaxis',
        'Response to lipopolysaccharide',
        'Positive regulation of cell activation',
        'Regulation of leukocyte proliferation',
        'Immune mediator production',
        
    ],
    '-log10(adj p-value)': [
        6.248998585,
        5.643628779,
        5.643628779,
        5.026869521,
        4.961651958,
        4.574806523,
        4.485073461

        


    ]
}


# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#bb0c00'
)




# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotM2up.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotM2up.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Chemotaxis',
        'Cell activation (immune response)',
        'Positive regulation of PI3K/Akt signaling',
        'Regulation of cell morphogenesis',
        'leukocyte cell-cell adhesion',
        'Regulation of leukocyte apoptotic process',
        
        
    ],
    '-log10(adj p-value)': [
        10.19689664,
        7.095273529,
        5.778535699,
        5.389585259,
        5.093060009,
        4.906433104
        
        
        
        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#4169E1'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotRESAPC ASHAM.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotRESAPC ASHAM.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'ECM organization',
        'Collagen fibril organization',
        'Bone development',
        'ECM assembly',
        'Response to TGF-β',
        'TGF-β receptor superfamily signaling',
        
    ],
    '-log10(adj p-value)': [
        10.29836152,
        9.408176655,
        4.995312643,
        4.958301884,
        4.753945972,
        4.018148235,


        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#4169E1'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotm2AYOV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotm2AYOV.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Protein kinase B activation',
        'Regulation of protein kinase activity',
        'Bone development',
        'Viral life cycle',
        'Humoral immune response',
        'Positive regulation of ERK signaling',
        
    ],
    '-log10(adj p-value)': [
        3.131654862,
        3.131654862,
        3.131654862,
        2.936180089,
        2.631459122,
        2.567557024

        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#bb0c00'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotM2up aged OV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotM2up aged OV.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Leukocyte cell-cell adhesion',
        'Collagen fibril organization',
        'ECM organization',
        'MHC class II–mediated antigen presentation',
        'MHC class II peptide loading',
        'Response to TGF-β',
        'Chemotaxis',
        'Positive regulation of leukocyte activation',
        'Glucose catabolic process'
        
        
    ],
    '-log10(adj p-value)': [
        6.015224181,
        5.865319703,
        5.796833688,
        5.796833688,
        5.187791275,
        4.730927546,
        4.715310772,
        4.708756413,
        4.425975015

        

        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#4169E1'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotM2 AGED OV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotM2 AGED OV.png

# %%
#RESIDENCE OV YOUNG

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'ECM organization',
        'Collagen fibril organization',
        'Lung development',
        'Bone development',
        'Response to TGF-β',
        'ECM assembly',
        'Cell-substrate adhesion',
        'Collagen metabolic process'
        
        
    ],
    '-log10(adj p-value)': [
        12.72552119,
        10.99969774,
        7.254744462,
        6.195488831,
        5.8352128,
        4.987328955,
        4.866145032,
        4.433041556,
        

        

        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#4169E1'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotRES YOUNG OV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotRES YOUNG OV.png

# %%
#RESIDEN AGED OV

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Cell-substrate adhesion',
        'ECM organization',
        'Collagen fibril organization',
        'Chemokine production',
        'Negative regulation of cell migration',
        'Response to TGF-β',
        'Biomineral tissue development',
        'Chemotaxis',
        'Cell-matrix adhesion',
        'Inflammatory mediator production',
        'Glucose catabolic process'
        
        
        
    ],
    '-log10(adj p-value)': [
        6.731133316,
        6.731133316,
        6.668270063,
        5.517590865,
        4.459172413,
        4.33814542,
        4.321088124,
        3.693524974,
        3.551692817,
        3.340590405,
        3.340590405

        
        

        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#4169E1'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotRES AGED OV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotRES AGED OV.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Response to macrophage CSFs',
        'Leukocyte migration',
        'Humoral immune response',
        'Positive regulation of protein localization',
        'Positive regulation of PI3K/AKT signaling',
        'Gland morphogenesis',
        'Positive regulation of protein transport',
        
        
    ],
    '-log10(adj p-value)': [
        3.569290776,
        3.569290776,
        3.569290776,
        3.311615304,
        3.311615304,
        3.199048316,
        3.199048316

        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#bb0c00'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotRESup aged OV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotRESup aged OV.png

# %%
#young lipid

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Collagen fibril organization',
        'ECM organization',
        'Extracellular structure organization',
        'Chemokine production'
        
        
        
        
    ],
    '-log10(adj p-value)': [
        7.032177498,
        6.564237326,
        6.564237326,
        4.29666212     

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#4169E1'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotRES AGED LIDID YOUNG UPOV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotRES AGED LIDID YOUNG UPOV.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Macrophage activation',
        'Myeloid leukocyte activation',
        'Response to type II interferon',
        'Response to lipopolysaccharide',
        'Positive regulation of monocyte chemotaxis',
        'T cell migration',
        'Regulation of nitric oxide metabolic process',
        'Phosphatidylcholine acyl-chain remodeling'
        
        
        
        
    ],
    '-log10(adj p-value)': [
        4.36335913,
        4.36335913,
        4.36335913,
        4.36335913,
        3.539067597,
        2.577605574,
        2.553943948,
        2.553943948


        
        

        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#bb0c00'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotRESup lipidYOUNG UP OV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotRESup lipidYOUNG UP OV.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Response to TGF-β',
        'Collagen fibril organization',
        'ECM organization',
        'Extracellular structure organization',
        'TGF-β receptor superfamily signaling pathway',
        'Receptor serine/threonine kinase signaling',
        
        
        
        
    ],
    '-log10(adj p-value)': [
        6.129133152,
        6.129133152,
        6.026948737,
        6.026948737,
        4.278269612,
        4.113783544
        

        
        

        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#4169E1'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plotRES AGED LIPIDOV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plotRES AGED LIPIDOV.png

# %%
#young Monocyte

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'ECM organization',
        'Extracellular structure organization',
        'Collagen fibril organization',
        'Bone development',
        'Response to mechanical stimulus',
        'Response to TGF-β stimulus',
        
        
        
        
        
    ],
    '-log10(adj p-value)': [
        10.40685397,
        10.40685397,
        9.299756869,
        5.423903695,
        4.004698788,
        3.936581583


        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#4169E1'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plot young mono downOV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plot young mono downOV.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'ECM organization',
        'Extracellular structure organization',
        'Glucose catabolic process',
        'Canonical glycolysis',
        'Collagen fibril organization',
        'Glycolysis via fructose-6-phosphate',
        'Cell-substrate adhesion',
        'NADH metabolic process',
        'Response to hypoxia',
        
        
        
        
        
        
    ],
    '-log10(adj p-value)': [
        14.54823614,
        14.54823614,
        11.46668041,
        11.44229079,
        11.33021301,
        10.0391888,
        9.600670929,
        8.993352455,
        8.143393886,
        


        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#4169E1'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plot Aged mono downOV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plot Aged mono downOV.png

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scanpy as sc  # Needed for sc.settings.figdir

# Set working directory
working_directory = r"P:/Tolulope/Manuscript/Yuan Analysis"
os.chdir(working_directory)

# Set the directory where figures will be saved
sc.settings.figdir = r"P:/Tolulope/Manuscript/Yuan Analysis/FIGURE_4"

# Example data
data = {
    'Description': [
        'Regulation of mononuclear cell migration',
        'Positive regulation of chemotaxis',
        'Leukocyte migration',
        'Mononuclear cell migration',
        'Chemotaxis',
        
        
        
        
        
    ],
    '-log10(adj p-value)': [
        2.423833277,
        2.118854171,
        2.028690876,
        2.028690876,
        2.028690876
        

        
        

        

    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort values in descending order to have the longest bar at the top
df = df.sort_values('-log10(adj p-value)', ascending=False)

# Plot
plt.figure(figsize=(5, 4))
ax = sns.barplot(
    x='-log10(adj p-value)',
    y='Description',
    data=df,
    color='#bb0c00'
)

# Formatting
ax.set_title('GO BP', fontsize=14)
ax.set_xlabel(r'$-\log_{10}(\mathrm{adj}\ p\text{-value})$', fontsize=12)
ax.set_ylabel('')  # <-- This removes "Description" label
plt.tight_layout()

# Save the figure
plot_path = os.path.join(sc.settings.figdir, 'enrichment_bar_plot mono UP OV.png')
plt.savefig(plot_path, dpi=300)
plt.close()

print(f"Figure saved to: {plot_path}")
# Out:
# Figure saved to: P:\Tolulope\Manuscript\Yuan Analysis\FIGURE_4\enrichment_bar_plot mono UP OV.png
